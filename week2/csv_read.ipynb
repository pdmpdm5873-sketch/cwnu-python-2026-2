# %% [markdown]
# <a href="https://colab.research.google.com/github/pdmpdm5873-sketch/cwnu-python-2026-2/blob/main/0909_colab_%EC%82%AC%EC%9A%A9%EB%B2%95_%EC%A0%95%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #제목1
#
# ##제목2
#
# ###제목3
#
# ***
#
#
# **진하게**
#
#
# ***
#
# 리스트
# 순서 없는 목록 -,+,*
#
# -안녕
#
# -안녕
#
# -안녕
#
# 순서 있는 목록 숫자 뒤에 점 (.) 이나 괄호 () 괄호
#
# 1.one
#
# 2.two
#
# 3.three
#
# 1) 하나
#
# 2) 둘
#
# 3) 셋
#
# ***
#
# 코드블럭
#
# 코드 앞뒤에 백틱 넣어주면 된다.
#
# `안뇽`
#
# ***
#
# 인용블록 >
#
# >Q1. 오늘 점심은?
#
# >A1. 굶기
# ***
#
# # 링크추가 [텍스트] {링크주소} 형식으로
#
# [네이버] {https://www.naver.com/} 에 오신걸 환영합니다.

# %%
# pandas의 역할은 csv 파일을 불러오는것
import pandas as pd
df = pd.read_csv("data.csv")
df.head()
# Out:
#   순번 과목
# 0  1.국어
# 1  2.영어
# 2  3.수학
# 3  4.사회
# 4  5.과학

# %%
# !ls
# Out:
# data.csv  drive  sample_data

# %%
# numpy는 계산, import는 도구 상자 불러오기

import numpy as np
import pandas as pd
a = np.array([1, 2, 3])
print(a.mean())
# Out:
# 2.0

# %%
# ! 기호를 붙이면 Python 코드가 아니라 시스템 명령을 실행,
# pip는  Package Installer for Python의 약자 , 파이썬(Python)의 표준 패키지 관리 시스템
# !pip install package-name
# 예시
# !pip install wordcloud
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for package-name: filename=package_name-0.1-py3-none-any.whl size=1229 sha256=554177344deefaa03dcafca62280666969615422ea8a6b14429625e54d3dde0a
#   Stored in directory: /root/.cache/pip/wheels/a1/0f/ab/19fecd3958a04b6fe3fb0d105f9e7d4182876db8c44cb1f1fc
# Successfully built package-name
# ...

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
print ('박동민')
print ('사학과')
print ("your's fater")
# Out:
# 박동민
# 사학과
# your's fater

# %%
#변수 지정

#문자열
name = "홍길동"
#정수
age = 20
score1 = 85
score2 = 95
score3 = 100
average = (score1 + score2) / 2
# Out:
# 홍길동
# 20
# 90.0

# %%
#리스트 → 여러 데이터 저장
#함수 → len, sum, max, min
#연산자 → / 로 평균 계산

scores = [1, 2, 3, 4, 5]
print("인원:", len(scores))
print("합계:", sum(scores))
print("최고:", max(scores))
print("최저:", min(scores))
print("평균:", sum(scores)/len(scores))
# Out:
# 인원: 5
# 합계: 15
# 최고: 5
# 최저: 1
# 평균: 3.0

# %%
'''
자주 만나는 오류와 해결 습관 오류는 “실패”가 아니라 Python이 보내는 설명 메시지

SyntaxError 문법 오류

괄호·따옴표·콜론 확인

NameError 이름 오류

변수명을 만들었는지 확인

TypeError 자료형 오류

문자와 숫자를 잘못 섞었는지 확인

FileNotFoundError 파일 오류

파일명과 경로 확인

해결 순서: 오류의 마지막 줄 읽기 → 해당 줄 확인 → 한 번에 하나씩 수정 → 다시 실행
'''
# Out:
# '\n자주 만나는 오류와 해결 습관 오류는 “실패”가 아니라 Python이 보내는 설명 메시지\n\nSyntaxError 문법 오류\n\n괄호·따옴표·콜론 확인\n\nNameError 이름 오류\n\n변수명을 만들었는지 확인\n\nTypeError 자료형 오류\n\n문자와 숫자를 잘못 섞었는지 확인\n\nFileNotFoundError 파일 오류\n\n파일명과 경로 확인\n\n해결 순서: 오류의 마지막 줄 읽기 → 해당 줄 확인 → 한 번에 하나씩 수정 → 다시 실행\n'

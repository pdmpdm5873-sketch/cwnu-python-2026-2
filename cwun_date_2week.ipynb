# %% [markdown]
# <a href="https://colab.research.google.com/github/pdmpdm5873-sketch/cwnu-python-2026-2/blob/main/cwun_date_2week.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
str(22.2)
# Out:
# '22.2'

# %%
socre = 1

# %%
a = 10
b = 3.5
c = "10"
d = a > 5
print(type(a))
print(type(b))
print(type(c))
print(type(d))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %%
del print  # 잘못 정의된 print 변수를 삭제하여 기본 함수 복구

so = 1 > 3
print(so)
# Out:
# False

# %%
print ("201" + "10")
# Out:
# 20110

# %%
num="22"
print("점수는;" + num)
# Out:
# 점수는;22

# %%
print("2026", "09", "14" , sep="-")
# Out:
# 2026-09-14

# %%
print("A", end=" ")
print("B")
# Out:
# A B

# %%
name="민수"
score=88
print(f"{name}: {score} 점")
# Out:
# 민수: 88 점

# %%
name = input("이름을 입력하세요: ")
#print("안녕하세요,", name)
print(f"안녕하세요, {name}")

city = input("사는 도시: ")
print(f"{city}에 살고 있군요!")
# Out:
# 이름을 입력하세요: k
# 안녕하세요, k
# 사는 도시: d
# d에 살고 있군요!

# %%
age = int(input("나이: "))
next_age = age + 1
print(next_age)
# Out:
# 나이: 20
# 21

# %%
이름 = input("이름을 입력하세요.")
학과 = input("학과를 입력하세요.")
나이 = int(input("나이를 입력하세요."))
print(f"이름: {이름}")
print(f"학과: {학과}")
print(f"나이: {나이}")
print(f"안녕하세요. 저는 {학과}, {이름}이고, {나이}살입니다")
# Out:
# 이름을 입력하세요.박
# 학과를 입력하세요.동
# 나이를 입력하세요.20
# 이름: 박
# 학과: 동
# 나이: 20
# 안녕하세요. 저는 동, 박이고, 20살입니다

# %%
/*-+
